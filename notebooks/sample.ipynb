# %%
import sys
import os
sys.path.append(os.path.abspath('../src'))

# %%
from main import cowsay

cowsay("Hi Eileen!")
# Out:
#  Hi Eileen!
#
#         \   ^__^
#          \  (oo)\_______
#             (__)\       )\/\
#                 ||----w |
#                 ||     ||

# %% [markdown]
# ![Eileen Collins](assets/astronaut.png)
